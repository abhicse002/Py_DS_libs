# %% [markdown]
# <a href="https://colab.research.google.com/github/abhicse002/Py_DS_libs/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Why Seaborn over Matplotlib
# *   Seaborn has simpler syntax for creating complex visualization, it has more appealing styles, color, palettes.
# *   Integrated with Pandas, so datasets can be loaded directly from seaborn library.
# *   It supports complex statistical Plots like FacetGrid, Pairplot, Pairplot.
# Supports statistical Estimation like Regression line, confidance intervals. Ex: lmplot, regplot
# *   Easy handling of plotting of Categorical data using BoxPlot, ViolinPlot, StripPlot, CatPlot compared to Mathplotlib
# *   Has good Palette coloring.
# *   Can automatically display Statistical Infos like Error Bars on Plots.
# *   Customizing the Plots is quite easy using themes like Grids.

# %% [markdown]
# 1.   palette :- deep, muted, pastel, dark, colorblind, bright, Set2, assent, paired, husl, cubehelix
# 2.   List item

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.__version__

sns.get_dataset_names()
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Themes and Color Palettes
cust_palette1 = sns.set_palette('Set1') # set the palette 1

sns.set(style='white', palette=cust_palette1) # Apply the Palette
sns.scatterplot(x=iris['sepal_length'], y=iris['sepal_width'], data=iris, hue='species')
plt.show()

# %%
custom_colors = ['#C71585', '#F0E68F', '#FF5733'] # Based on number of Categorical Varibales mentioned in hue and dataset
sns.set_palette(custom_colors) # Set the custom color palette
sns.set_style('darkgrid') # set the Theme(Style):- Dark, darkgrid, white, whitegrid
sns.scatterplot(x=iris['petal_length'], y=iris['petal_width'], data=iris, hue='species')
plt.show()

# %%
arr1 = np.arange(0,8,0.3) # 8/0.5 = 16 elements
print(arr1)
# Out:
# [0.  0.3 0.6 0.9 1.2 1.5 1.8 2.1 2.4 2.7 3.  3.3 3.6 3.9 4.2 4.5 4.8 5.1
#  5.4 5.7 6.  6.3 6.6 6.9 7.2 7.5 7.8]

# %%
np.sin(arr1)
# Out:
# array([ 0.        ,  0.29552021,  0.56464247,  0.78332691,  0.93203909,
#         0.99749499,  0.97384763,  0.86320937,  0.67546318,  0.42737988,
#         0.14112001, -0.15774569, -0.44252044, -0.68776616, -0.87157577,
#        -0.97753012, -0.99616461, -0.92581468, -0.77276449, -0.55068554,
#        -0.2794155 ,  0.0168139 ,  0.31154136,  0.57843976,  0.79366786,
#         0.93799998,  0.99854335])

# %%
# for resizing we can use subplot or figsize

# %%
# kind = hist, kde
# stat = count, prob, density, freq
# bins = only if kind is hist (range like 100-200, 200-300 then bin size is 100, so max-min/bin size is the no of Bins)
# hue = applicable for categorical values
# palette = will be applicable only if hue is mentioned as its applicable for coloring catrgorical columns
# aspect
# color
# height

plt.figure(figsize=(10,5), dpi=100) # What is dpi ..?
sns.displot(x='species', y='sepal_length', data=iris, kind='hist', bins=25)
plt.show()

# %%
# Histogram
# Used for understanding distribution of continuous variables
# Used for straightforward, detailed visualization of single var dist, with control over binning. Used for basic, single-variable analysis.
# stat = probability, density, probability
# kde = You can identify whether the data follows a normal distribution, is skewed, or has multiple modes (peaks)
# bins = When you do not specify the number of bins or bin width, Seaborn will use an automatic binning algorithm to determine the bin size
plt.figure(figsize=(10,6))
sns.histplot(x='sepal_length', data=iris, kde=True, hue='species', stat='count')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Histogram')
plt.show()

# %%
# Dist Plot
# more complex visualizations involving multiple types of distribution plots,
# comparisons across subsets, or faceting.
# Best for exploratory data analysis and when you need to compare distributions across different groups or facets.

sns.displot(data=iris, x='petal_length', kind='hist', bins=20, kde=True)
plt.title('Histogram with KDE Curve')
plt.xlabel('Petal Length')
plt.ylabel('Density')
plt.show()

# %%
# plot the kde, ot get density line
# sns.kdeplot(x='species', data=iris, color='dark', color='black', height=int/float, fill=True)

# %%
# sns.rugplot(x/y=numerical, hue='categorical', data=df, color='black', height=int/float, fill=True)

# %%
# Box plot or Whisker Plot
# 5 point summary
# checking outliers
# Cental tendancy, outliers & what is the spread.
sns.boxplot(data=iris, color='grey')
plt.title('Horizontal Box Plot of Petal Length by Species')
plt.xlabel('Petal Length')
plt.show()

print(iris['sepal_length'].mean())
print(iris['sepal_width'].mean())
print(iris['petal_length'].mean())
print(iris['petal_width'].mean())
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
# 5.843333333333334
# 3.0573333333333337
# 3.7580000000000005
# 1.1993333333333336

# %%
# BarPlot
# barplot used with different categorical variable and countplot used with single categorical varibale
# CI(confidance interval) = provides a range of values within which we can be confident that the true population parameter lies
# sns.barplot(x='categorical', y='numerical', hue='categorical', color='red', errorbar=('ci', 85), estimator, palette) -- (errorbar = confidance level ..?)
sns.barplot(x='species', y='sepal_width', data=iris, edgecolor='black', linewidth=0.5, ci='sd')
plt.title('Average Total Bill per Day')
plt.xlabel('Species')
plt.ylabel('Sepal Width')
plt.show()
# Out:
# <ipython-input-127-f0657f5eb736>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(x='species', y='sepal_width', data=iris, edgecolor='black', linewidth=0.5, ci='sd')

# %%
# LINEAR MODEL PLOT, lmplot used for Multi variables
# Used for represeneting Facet data (create multiple subplots)
sns.set_theme(style='ticks')
sns.lmplot(
    data=iris,
    x='petal_width',
    y='petal_length',
    hue='species',
    palette="dark",
    ci=None,
    height=6,     # height of the Graph
    scatter_kws={
        "s": 10,  # s = size of the dot (data point)
        "alpha": 0.2  # alpha = transparent, opaque
    }
)
plt.show()

# %%
# sns.countplot(x='categorical', y='numerical', hue='categorical', color='red', errorbar=('ci', 85), estimator, palette) -- (errorbar = confidance level ..?)
print(iris.value_counts())
sns.countplot(x='species', data=iris, color='red', hue='species')

plt.title('Count of Species')
plt.show()
# Out:
# sepal_length  sepal_width  petal_length  petal_width  species
# 5.8           2.7          5.1           1.9          virginica     2
# 6.2           2.2          4.5           1.5          versicolor    1
#               2.9          4.3           1.3          versicolor    1
#               3.4          5.4           2.3          virginica     1
# 6.3           2.3          4.4           1.3          versicolor    1
#                                                                    ..
# 5.4           3.9          1.3           0.4          setosa        1
#                            1.7           0.4          setosa        1
# 5.5           2.3          4.0           1.3          versicolor    1
#               2.4          3.7           1.0          versicolor    1
# 7.9           3.8          6.4           2.0          virginica     1
# Name: count, Length: 149, dtype: int64
# <ipython-input-83-5e515c8c8659>:3: FutureWarning:
#
# ...

# %%
# Scatterplot with multiple semantics
sns.set_theme(style="whitegrid")
f, ax = plt.subplots(figsize=(8.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["versicolor", "setosa", "virginica"]
sns.scatterplot(
    x="petal_length",
    y="petal_width",
    hue="species",
    # size="depth",
    palette="ch:r=-.2,d=.3_r",
    hue_order=clarity_ranking,
    # linewidth=1,
    data=iris,
    # ax=ax
)
plt.show()

# %%
# Linear regression model fit between two variables

# CI - the shaded region represents the UNCERTAINITY or VARIABILITY in the estimate of Regression Line
# Wider the shaded Region more is the uncertainity and less Precision
# The shaded region explain if we allow 95% upto threshold on data, then what is the width of the shaded region,
# if Wider then more uncertainity & Less Precise, if smaller shaded Region, then Less the Uncertainity and More Precise
# works well with just two continuous variable, quick, straightforward regression plots
sns.regplot(
    x='petal_length',
    y='petal_width',
    data=iris,
    ci=95, # ci=95, it means that there's a 95% chance that the true regression line falls within this shaded area
    order=1, # Order 2 = Fits a linear regression model, Order 2 = fits a quadratic (parabolic) curve, Order 3 = Fits a cubic curve
    logx=False # Fits the regression model with a log-transformed x-axis, which is useful for data with an exponential relationship
)

# Customize the plot
plt.title('Regression Plot of Petal Length vs Width')
plt.show()

# %%
# scatter plot + histplot
sns.jointplot()

# %%
# pairplot

# %%
# stripplot

# %%
# swarmplot
sns.swarmplot()

# %%
# violin plot

# %%
# catplot

# %%
# heatmap
# plot correlation

# %%
# Plotting the seaborn plot in axes
